# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

# %% [markdown]
# # IMPORTING DATASET

# %%
data = pd.read_csv('mushrooms_data.csv')

# %%
data.head(10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# ...

# %% [markdown]
# # DATASET INFORMATION

# %%
#number of rows and columns

data.shape
# Out:
# (8124, 23)

# %%
# see if there are any null values and what data types they are


data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
# confirming each column's data type

data.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
#column names

data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
#number of unique values present in each columns

data.nunique()
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %%
# Displaying the count of each variable in each columns

for i in data:
  print('\n\nNumber of distinct elements in column :-' +i)
  print(data[i].value_counts())
# Out:
# Number of distinct elements in column :-class
# e    4208
# p    3916
# Name: class, dtype: int64
#
#
# Number of distinct elements in column :-cap-shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64
#
#
# Number of distinct elements in column :-cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64
#
#
# Number of distinct elements in column :-cap-color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# r      16
# u      16
# Name: cap-color, dtype: int64
#
#
# Number of distinct elements in column :-bruises
# f    4748
# t    3376
# Name: bruises, dtype: int64
#
#
# Number of distinct elements in column :-odor
# n    3528
# f    2160
# y     576
# s     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64
#
#
# Number of distinct elements in column :-gill-attachment
# f    7914
# a     210
# ...

# %%
# It is clear that there is '?' in colmn named 'stalk-root' and therefore percentage of ? in that column is given by 

data['stalk-root'].value_counts()/len(data['stalk-root'])*100
# Out:
# b    46.479567
# ?    30.526834
# e    13.786312
# c     6.843919
# r     2.363368
# Name: stalk-root, dtype: float64

# %% [markdown]
# The atribute veil_type can be deleted because it only takes one value, the rest of attributes don't show any problem.

# %%
# We can simply remove stalk root column as 30 percentage of that column is missing.

# %%
#dropping veil-type because it has got one value and stalk root

data.drop(['veil-type','stalk-root'],axis=1,inplace=True)

# %%
# making sure there are no nulls

data.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# see how many mushrooms are edible or poisonous
#The target attribute is going to be the mushroom class.Edible or poisonous are the 2 attributes.. 
data['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
caps = data['cap-shape'].value_counts()
print(caps)
cap_labels = caps.axes[0].tolist()
print(cap_labels)
poisonous = []
edible = [] 
ind = np.arange(6)
print(ind)
for cap in cap_labels:
    size = len(data[data['cap-shape'] == cap].index)
    edibles = len(data[(data['cap-shape'] == cap) & (data['class'] == 'e')].index)
    edible.append(edibles)
    
    poisonous.append(size-edibles)
print("Edible:",edible)
print("Poisonous:",poisonous)
# Out:
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64
# ['x', 'f', 'k', 'b', 's', 'c']
# [0 1 2 3 4 5]
# Edible: [1948, 1596, 228, 404, 32, 0]
# Poisonous: [1708, 1556, 600, 48, 0, 4]

# %%
column_list = data.columns.values.tolist()
for column_name in column_list:
    print(column_name ,"=",data[column_name].unique())
# Out:
# class = ['p' 'e']
# cap-shape = ['x' 'b' 's' 'f' 'k' 'c']
# cap-surface = ['s' 'y' 'f' 'g']
# cap-color = ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises = ['t' 'f']
# odor = ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-attachment = ['f' 'a']
# gill-spacing = ['c' 'w']
# gill-size = ['n' 'b']
# gill-color = ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape = ['e' 't']
# stalk-surface-above-ring = ['s' 'f' 'k' 'y']
# stalk-surface-below-ring = ['s' 'f' 'y' 'k']
# stalk-color-above-ring = ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below-ring = ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# veil-color = ['w' 'n' 'o' 'y']
# ring-number = ['o' 't' 'n']
# ring-type = ['p' 'e' 'l' 'f' 'n']
# spore-print-color = ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population = ['s' 'n' 'a' 'v' 'y' 'c']
# habitat = ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %% [markdown]
# # VISUALISATIONS

# %%
plt.figure()
pd.Series(data['class']).value_counts().sort_index().plot(kind = 'bar')
plt.ylabel("Count")
plt.xlabel("class")
plt.title('Number of poisonous/edible mushrooms (0=edible, 1=poisonous)');

# %% [markdown]
# The dataset is balanced.

# %%
import seaborn as sb
#Cap features
plt.figure(figsize=(14,14))
plt.subplot(2,2,1)
sb.countplot(x='cap-shape',hue='class',data=data)
plt.title('Cap shape vs Class')
plt.subplot(2,2,2)
sb.countplot(x='cap-surface',hue='class',data=data)
plt.title('Cap surface vs Class')
plt.xticks(rotation=0)
plt.subplot(2,2,3)
sb.countplot(x='cap-color',hue='class',data=data)
plt.xticks(rotation=40)
plt.title('Cap color vs Class')
plt.show()
plt.subplots_adjust(hspace=0.3)

# %% [markdown]
# 1) Mushroom with sunken cap shape is edible (but the number of data points is less).
# 2) Cap surface doesnt give much idea about the mushroom class.
# 3) Purple and green cap color mushrooms are edible (less data points).

# %% [markdown]
# # LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()
for col in data.columns:

    data[col] = lab.fit_transform(data[col])

data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-above-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# ...

# %%
#In class, 1 indicates poisonous and 0 indictes edible.

# %%
column_list = data.columns.values.tolist()
for column_name in column_list:
    print(column_name ,"=",data[column_name].unique())
# Out:
# class = [1 0]
# cap-shape = [5 0 4 2 3 1]
# cap-surface = [2 3 0 1]
# cap-color = [4 9 8 3 2 5 0 7 1 6]
# bruises = [1 0]
# odor = [6 0 3 5 2 1 8 7 4]
# gill-attachment = [1 0]
# gill-spacing = [0 1]
# gill-size = [1 0]
# gill-color = [ 4  5  2  7 10  3  9  1  0  8 11  6]
# stalk-shape = [0 1]
# stalk-surface-above-ring = [2 0 1 3]
# stalk-surface-below-ring = [2 0 3 1]
# stalk-color-above-ring = [7 3 6 4 0 2 5 1 8]
# stalk-color-below-ring = [7 6 3 0 4 2 8 5 1]
# veil-color = [2 0 1 3]
# ring-number = [1 2 0]
# ring-type = [4 0 2 1 3]
# spore-print-color = [2 3 6 1 7 5 4 8 0]
# population = [3 2 0 4 5 1]
# habitat = [5 1 3 0 4 6 2]

# %%
data.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
x = data.drop('class', axis = 1) # X will act as predictors variable
y = data['class'] # y will act as response variable

# %% [markdown]
# # Standardisation

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = scaler.fit_transform(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#                  0             1             2             3             4   \
# count  8.124000e+03  8.124000e+03  8.124000e+03  8.124000e+03  8.124000e+03
# mean  -5.423612e-15  4.217659e-17  4.423065e-15 -1.797258e-14 -3.590486e-15
# std    1.000062e+00  1.000062e+00  1.000062e+00  1.000062e+00  1.000062e+00
# min   -2.087047e+00 -1.486157e+00 -1.769549e+00 -8.432296e-01 -1.970316e+00
# 25%   -8.403434e-01 -1.486157e+00 -5.910746e-01 -8.432296e-01 -1.019565e+00
# 50%   -2.169915e-01  1.401279e-01 -1.982498e-01 -8.432296e-01  4.065620e-01
# 75%    1.029712e+00  9.532704e-01  1.373049e+00  1.185917e+00  4.065620e-01
# max    1.029712e+00  9.532704e-01  1.765874e+00  1.185917e+00  1.832689e+00
#
#                  5             6             7             8             9   \
# count  8.124000e+03  8.124000e+03  8.124000e+03  8.124000e+03  8.124000e+03
# mean  -2.478055e-14  8.422977e-15  8.636999e-15  1.302651e-14 -6.287000e-15
# ...

# %% [markdown]
# # CORRELATION MATRIX

# %%
plt.figure(figsize=(16,14))
sns.heatmap(data.corr(), annot=True)
plt.title('Correlations mushrooms')
# Out:
# Text(0.5, 1.0, 'Correlations mushrooms')

# %% [markdown]
# # MODEL SELECTION

# %% [markdown]
# It is a classification model.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state =42)
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,f1_score
from sklearn import metrics
accuracy =[]
fscore =[]

# %%
# Guassian Naive bayes
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test, y_pred)*100)
print("F1 score is: ",f1_score(y_test, y_pred,average = 'micro')*100)

accuracy.append(metrics.accuracy_score(y_test, y_pred))

fscore.append(metrics.f1_score(y_test, y_pred))

z=pd.DataFrame({'actual':y_test,'predicted':y_pred})
z.head()
# Out:
# Accuracy is:  92.8219852337982
# F1 score is:  92.8219852337982
#       actual  predicted
# 1971       0          0
# 6654       1          1
# 5606       1          1
# 3332       0          0
# 6988       1          1

# %%
#confusion matrix 
confusion_matrix(y_test, y_pred)
# Out:
# array([[1173,   84],
#        [  91, 1090]], dtype=int64)

# %%
#Bernoulli Naive Bayes
from sklearn.naive_bayes import BernoulliNB
classifier = BernoulliNB()
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test, y_pred)*100)
print("F1 score is: ",f1_score(y_test, y_pred,average = 'micro')*100)

accuracy.append(metrics.accuracy_score(y_test, y_pred))

fscore.append(metrics.f1_score(y_test, y_pred))

z=pd.DataFrame({'actual':y_test,'predicted':y_pred})
z.head()
# Out:
# Accuracy is:  88.14602132895816
# F1 score is:  88.14602132895816
#       actual  predicted
# 1971       0          0
# 6654       1          1
# 5606       1          1
# 3332       0          0
# 6988       1          1

# %%
#confusion matrix 
confusion_matrix(y_test, y_pred)
# Out:
# array([[1198,   59],
#        [ 230,  951]], dtype=int64)

# %%
#LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train,y_train)
y_pred= model.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test, y_pred)*100)
print("F1 score is: ",f1_score(y_test, y_pred,average = 'micro')*100)

accuracy.append(metrics.accuracy_score(y_test, y_pred))

fscore.append(metrics.f1_score(y_test, y_pred))

z=pd.DataFrame({'actual':y_test,'predicted':y_pred})
print(z.head())

data['class'][1971]
# Out:
# Accuracy is:  94.66776045939295
# F1 score is:  94.66776045939295
#       actual  predicted
# 1971       0          0
# 6654       1          1
# 5606       1          1
# 3332       0          0
# 6988       1          1
# 0

# %%
#confusion matrix 
confusion_matrix(y_test, y_pred)
# Out:
# array([[1199,   58],
#        [  72, 1109]], dtype=int64)

# %%
#KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier()
classifier.fit(x_train,y_train)
y_pred= classifier.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test, y_pred)*100)
print("F1 score is: ",f1_score(y_test, y_pred,average = 'micro')*100)

accuracy.append(metrics.accuracy_score(y_test, y_pred))

fscore.append(metrics.f1_score(y_test, y_pred))

z=pd.DataFrame({'actual':y_test,'predicted':y_pred})
z.head()
# Out:
# Accuracy is:  100.0
# F1 score is:  100.0
#       actual  predicted
# 1971       0          0
# 6654       1          1
# 5606       1          1
# 3332       0          0
# 6988       1          1

# %%
#confusion matrix 
confusion_matrix(y_test, y_pred)
# Out:
# array([[1257,    0],
#        [   0, 1181]], dtype=int64)

# %%
#DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred= model.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test, y_pred)*100)
print("F1 score is: ",f1_score(y_test, y_pred,average = 'micro')*100)

accuracy.append(metrics.accuracy_score(y_test, y_pred))

fscore.append(metrics.f1_score(y_test, y_pred))

z=pd.DataFrame({'actual':y_test,'predicted':y_pred})
z.head()
# Out:
# Accuracy is:  100.0
# F1 score is:  100.0
#       actual  predicted
# 1971       0          0
# 6654       1          1
# 5606       1          1
# 3332       0          0
# 6988       1          1

# %%
#confusion matrix 
confusion_matrix(y_test, y_pred)
# Out:
# array([[1257,    0],
#        [   0, 1181]], dtype=int64)

# %%
#SVM
from sklearn.svm import SVC
svm_linear = SVC()
svm_linear.fit(x_train,y_train)
y_pred= svm_linear.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test, y_pred)*100)
print("F1 score is: ",f1_score(y_test, y_pred,average = 'micro')*100)

accuracy.append(metrics.accuracy_score(y_test, y_pred))

fscore.append(metrics.f1_score(y_test, y_pred))

z=pd.DataFrame({'actual':y_test,'predicted':y_pred})
z.head()
# Out:
# Accuracy is:  100.0
# F1 score is:  100.0
#       actual  predicted
# 1971       0          0
# 6654       1          1
# 5606       1          1
# 3332       0          0
# 6988       1          1

# %%
#confusion matrix 
confusion_matrix(y_test, y_pred)
# Out:
# array([[1257,    0],
#        [   0, 1181]], dtype=int64)

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
forest= RandomForestClassifier(n_estimators=100)
forest.fit(x_train,y_train)
y_pred_rf = forest.predict(x_test)
print("Accuracy is: ",accuracy_score(y_test, y_pred_rf)*100)
print("F1 score is: ",f1_score(y_test, y_pred_rf,average = 'micro')*100)

accuracy.append(metrics.accuracy_score(y_test, y_pred_rf))

fscore.append(metrics.f1_score(y_test, y_pred_rf))

z=pd.DataFrame({'actual':y_test,'predicted':y_pred_rf})
z.head()
# Out:
# Accuracy is:  100.0
# F1 score is:  100.0
#       actual  predicted
# 1971       0          0
# 6654       1          1
# 5606       1          1
# 3332       0          0
# 6988       1          1

# %%
#confusion matrix 
confusion_matrix(y_test, y_pred)
# Out:
# array([[1257,    0],
#        [   0, 1181]], dtype=int64)

# %%
#plotting different accuracy
plt.plot([1,2,3,4,5,6,7], accuracy, 'ro')
plt.xticks([1,2,3,4,5,6,7],['GNB','BNB','LogRegression','KNN','Tree', 'SVM','Forest'])
plt.ylabel('Accuracy')
plt.show()

# %%
#plotting f1 score of different models
plt.plot([1,2,3,4,5,6,7], fscore, 'ro')
plt.xticks([1,2,3,4,5,6,7],['GNB','BNB','LogRegression','KNN','Tree', 'SVM','Forest'])
plt.ylabel('F-score')
plt.show()

# %% [markdown]
# # Except Naive bayes and Logistic regression all other models are having 100% accuracy.

# %% [markdown]
# # Guassian Naive Bayes is having only 92.8 % accuracy

# %% [markdown]
# # Bernoulli Naive Bayes is having 88.16 % accuracy only.

# %%
#Use pickle to save our model so that we can use it later

import pickle 
# Saving model to disk
pickle.dump(forest, open('model.pkl','wb'))
model=pickle.load(open('model.pkl','rb'))
